# %% [markdown]
# # Kapitel 13 – Übungssammlung und Lösungen
#
# Dieses Notebook enthält Übungen zum Wiederholen der wichtigsten Tkinter-Themen.
# Die Aufgaben sind in drei Schwierigkeitsstufen eingeteilt.

# %% [markdown]
# # Hinweise
#
# Versuche jede Aufgabe zunächst selbst zu lösen.
#
# Erst danach solltest du die Musterlösung ansehen.

# %% [markdown]
# # 🟢 Leichte Übungen

# %% [markdown]
# ## Aufgabe 1
#
# Erstelle ein Fenster mit einem Label.

# %% [markdown]
# ### Lösung (Idee)
#
# - Benutze die passenden Tkinter-Widgets.
# - Verwende `pack()` oder `grid()`.

# %% [markdown]
# ## Aufgabe 2
#
# Füge einen Button hinzu.

# %% [markdown]
# ### Lösung (Idee)
#
# - Benutze die passenden Tkinter-Widgets.
# - Verwende `pack()` oder `grid()`.

# %% [markdown]
# ## Aufgabe 3
#
# Erstelle zwei Entry-Felder.

# %% [markdown]
# ### Lösung (Idee)
#
# - Benutze die passenden Tkinter-Widgets.
# - Verwende `pack()` oder `grid()`.

# %% [markdown]
# ## Aufgabe 4
#
# Ändere den Fenstertitel.

# %% [markdown]
# ### Lösung (Idee)
#
# - Benutze die passenden Tkinter-Widgets.
# - Verwende `pack()` oder `grid()`.

# %% [markdown]
# ## Aufgabe 5
#
# Ändere die Hintergrundfarbe.

# %% [markdown]
# ### Lösung (Idee)
#
# - Benutze die passenden Tkinter-Widgets.
# - Verwende `pack()` oder `grid()`.

# %% [markdown]
# ## Aufgabe 6
#
# Verwende ein LabelFrame.

# %% [markdown]
# ### Lösung (Idee)
#
# - Benutze die passenden Tkinter-Widgets.
# - Verwende `pack()` oder `grid()`.

# %% [markdown]
# ## Aufgabe 7
#
# Erstelle eine Listbox.

# %% [markdown]
# ### Lösung (Idee)
#
# - Benutze die passenden Tkinter-Widgets.
# - Verwende `pack()` oder `grid()`.

# %% [markdown]
# ## Aufgabe 8
#
# Füge Einträge zur Listbox hinzu.

# %% [markdown]
# ### Lösung (Idee)
#
# - Benutze die passenden Tkinter-Widgets.
# - Verwende `pack()` oder `grid()`.

# %% [markdown]
# ## Aufgabe 9
#
# Zeige eine Messagebox an.

# %% [markdown]
# ### Lösung (Idee)
#
# - Benutze die passenden Tkinter-Widgets.
# - Verwende `pack()` oder `grid()`.

# %% [markdown]
# ## Aufgabe 10
#
# Erstelle eine Combobox.

# %% [markdown]
# ### Lösung (Idee)
#
# - Benutze die passenden Tkinter-Widgets.
# - Verwende `pack()` oder `grid()`.

# %% [markdown]
# # 🟡 Mittlere Übungen

# %% [markdown]
# ## Aufgabe 1
#
# Erstelle ein Login-Fenster.

# %% [markdown]
# ### Hinweise
#
# - Teile dein Programm in Funktionen auf.
# - Verwende sprechende Variablennamen.
# - Teste jede Änderung einzeln.

# %% [markdown]
# ## Aufgabe 2
#
# Programmiere eine ToDo-Liste.

# %% [markdown]
# ### Hinweise
#
# - Teile dein Programm in Funktionen auf.
# - Verwende sprechende Variablennamen.
# - Teste jede Änderung einzeln.

# %% [markdown]
# ## Aufgabe 3
#
# Erstelle einen BMI-Rechner.

# %% [markdown]
# ### Hinweise
#
# - Teile dein Programm in Funktionen auf.
# - Verwende sprechende Variablennamen.
# - Teste jede Änderung einzeln.

# %% [markdown]
# ## Aufgabe 4
#
# Nutze StringVar für Eingaben.

# %% [markdown]
# ### Hinweise
#
# - Teile dein Programm in Funktionen auf.
# - Verwende sprechende Variablennamen.
# - Teste jede Änderung einzeln.

# %% [markdown]
# ## Aufgabe 5
#
# Zeige die aktuelle Uhrzeit mit after().

# %% [markdown]
# ### Hinweise
#
# - Teile dein Programm in Funktionen auf.
# - Verwende sprechende Variablennamen.
# - Teste jede Änderung einzeln.

# %% [markdown]
# ## Aufgabe 6
#
# Erstelle ein Kontextmenü.

# %% [markdown]
# ### Hinweise
#
# - Teile dein Programm in Funktionen auf.
# - Verwende sprechende Variablennamen.
# - Teste jede Änderung einzeln.

# %% [markdown]
# ## Aufgabe 7
#
# Erstelle ein Menü mit Datei und Hilfe.

# %% [markdown]
# ### Hinweise
#
# - Teile dein Programm in Funktionen auf.
# - Verwende sprechende Variablennamen.
# - Teste jede Änderung einzeln.

# %% [markdown]
# ## Aufgabe 8
#
# Zeichne Formen auf einem Canvas.

# %% [markdown]
# ### Hinweise
#
# - Teile dein Programm in Funktionen auf.
# - Verwende sprechende Variablennamen.
# - Teste jede Änderung einzeln.

# %% [markdown]
# ## Aufgabe 9
#
# Verschiebe ein Canvas-Objekt.

# %% [markdown]
# ### Hinweise
#
# - Teile dein Programm in Funktionen auf.
# - Verwende sprechende Variablennamen.
# - Teste jede Änderung einzeln.

# %% [markdown]
# ## Aufgabe 10
#
# Erstelle ein Notebook mit zwei Tabs.

# %% [markdown]
# ### Hinweise
#
# - Teile dein Programm in Funktionen auf.
# - Verwende sprechende Variablennamen.
# - Teste jede Änderung einzeln.

# %% [markdown]
# # 🔴 Schwierige Übungen

# %% [markdown]
# ## Projekt 1
#
# Entwickle einen kleinen Texteditor.

# %% [markdown]
# ### Mögliche Bestandteile
#
# - Label
# - Button
# - Entry
# - Text
# - Listbox
# - Menu
# - Messagebox

# %% [markdown]
# ## Projekt 2
#
# Erstelle ein Quiz-Spiel.

# %% [markdown]
# ### Mögliche Bestandteile
#
# - Label
# - Button
# - Entry
# - Text
# - Listbox
# - Menu
# - Messagebox

# %% [markdown]
# ## Projekt 3
#
# Programmiere ein Zahlenratespiel.

# %% [markdown]
# ### Mögliche Bestandteile
#
# - Label
# - Button
# - Entry
# - Text
# - Listbox
# - Menu
# - Messagebox

# %% [markdown]
# ## Projekt 4
#
# Erstelle einen Passwortgenerator.

# %% [markdown]
# ### Mögliche Bestandteile
#
# - Label
# - Button
# - Entry
# - Text
# - Listbox
# - Menu
# - Messagebox

# %% [markdown]
# ## Projekt 5
#
# Entwickle eine Kontaktverwaltung.

# %% [markdown]
# ### Mögliche Bestandteile
#
# - Label
# - Button
# - Entry
# - Text
# - Listbox
# - Menu
# - Messagebox

# %% [markdown]
# # Allgemeine Tipps
#
# - Plane dein Programm zuerst auf Papier.
# - Schreibe kleine Funktionen.
# - Teste häufig.
# - Lies Fehlermeldungen aufmerksam.
# - Nutze Kommentare nur dort, wo sie hilfreich sind.

# %% [markdown]
# # Abschluss
#
# Herzlichen Glückwunsch!
#
# Du hast die Grundlagen von Tkinter kennengelernt und zahlreiche Übungen bearbeitet.
#
# Jetzt bist du bereit, eigene Desktop-Anwendungen mit Python zu entwickeln.
