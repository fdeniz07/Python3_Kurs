# %% [markdown]
# # Kapitel 36.6 - Sicherheitsreviews, Checklisten und Release Gates
#
# Zum Abschluss lernst du, wie Sicherheitsqualitaet in Teamprozesse und Release-Entscheidungen eingebettet wird.

# %% [markdown]
# ## Lernziele
#
# - Security Reviews strukturiert durchfuehren
# - Release Gates mit klaren Kriterien definieren
# - technische und organisatorische Massnahmen verzahnen

# %%
release_gate = {
    'sast_passed': True,
    'dependency_scan_passed': True,
    'critical_findings': 0,
    'security_tests_passed': True
}
go_live = all([release_gate['sast_passed'], release_gate['dependency_scan_passed'], release_gate['security_tests_passed'], release_gate['critical_findings'] == 0])
print('GO_LIVE=', go_live)

# %% [markdown]
# ## Fallstudie (Praxis)
#
# Kurz vor Release wird eine kritische Abhaengigkeitsschwachstelle gefunden. Definiere ein Vorgehen fuer RisikoabwÃ¤gung, Hotfix-Plan und Kommunikationspfad.

# %% [markdown]
# ## Haeufige Fehler und Debugging-Checkliste
#
# - Security Findings ohne Priorisierung
# - unklare Verantwortlichkeiten bei kritischen Befunden
# - Freigabe trotz nicht geschlossener High-Risk-Tickets

# %% [markdown]
# ## Uebung
#
# Erstelle eine Security-Release-Checkliste mit mindestens zehn Pruefpunkten fuer ein Backend-Projekt.

# %% [markdown]
# ## Pruefungsfragen und Kurzloesungen
#
# 1. Warum sind Security Release Gates fuer Teams wichtig?
# Kurzloesung: Sie machen Sicherheitsanforderungen verbindlich und verhindern risikoreiche Freigaben unter Zeitdruck.

# %% [markdown]
# ## Technischer Tiefgang
#
# Dieses Kapitel wird auf Produktionsniveau relevant, wenn Begriffe praezise verwendet, Abhaengigkeiten explizit gemacht und Sicherheitsannahmen laufend verifiziert werden.
# Im Fokus stehen Nachvollziehbarkeit, Verteidigung in Schichten und reproduzierbare Sicherheitsentscheidungen.

# %% [markdown]
# ## Zentrale Fachbegriffe
#
# Security Gate
# SAST
# DAST
# Dependency Scan
# Risk Acceptance
# Compensating Control

# %%
# Release-Gate-Bewertung
gate={"critical_findings":0,"sast":True,"deps":True,"security_tests":True}
ready = gate["critical_findings"]==0 and gate["sast"] and gate["deps"] and gate["security_tests"]
print("release_ready", ready)

# %% [markdown]
# ## Architektur- und Betriebsbezug
#
# Leite fuer dieses Thema mindestens drei konkrete Team-Standards ab (z. B. Policy, Logging-Regel, Release-Gate).
# Definiere ausserdem, wie Verstosse sichtbar gemacht und innerhalb eines Sprints behoben werden.

# %% [markdown]
# ## Erweiterte Uebung (Projektmodus)
#
# 1. Erstelle eine kurze technische Richtlinie mit klaren Muss-/Soll-Regeln.
# 2. Leite daraus mindestens zwei automatisierbare Checks fuer CI/CD ab.
# 3. Formuliere ein Review-Protokoll mit Rollen, Entscheidungslogik und Eskalation.
