# %% [markdown]
# # Python Module – Aufgaben & Lösungen
# Thema: `math`-Modul, eigene Funktionen, Schleifen und Import-Methoden

# %% [markdown]
# ## a) math-Modul importieren und Quadratwurzel berechnen
#
# **Aufgabe:** Gebe an, wie du das Modul `math` in Python importierst und verwende eine Funktion aus diesem Modul, um die Quadratwurzel von 256 zu berechnen.

# %%
import math

ergebnis = math.sqrt(256)
print(ergebnis)  # Ausgabe: 16.0
# Out:
# 16.0

# %% [markdown]
# ## b) Kreisumfang mit math.pi berechnen
#
# **Aufgabe:** Erstelle eine Variable `radius` mit dem Wert 7. Berechne den Umfang eines Kreises unter Verwendung der Variable `radius` und der Konstante `pi` aus dem Modul `math`. Schreibe das Ergebnis in eine neue Variable `umfang` und gib sie aus.

# %%
import math

radius = 7
umfang = 2 * math.pi * radius
print(umfang)  # Ausgabe: 43.982297150257104
# Out:
# 43.982297150257104

# %% [markdown]
# ## c) Eigene Funktion: Fahrenheit → Celsius
#
# **Aufgabe:** Beschreibe, wie du eine eigene Funktion namens `fahrenheit_zu_celsius` definierst, die eine Temperatur in Fahrenheit entgegennimmt und die entsprechende Temperatur in Celsius zurückgibt. Verwende diese Funktion anschließend, um die Temperatur 68°F in Celsius umzurechnen und das Ergebnis auszugeben.

# %%
def fahrenheit_zu_celsius(fahrenheit):
    celsius = (fahrenheit - 32) * 5 / 9
    return celsius

ergebnis = fahrenheit_zu_celsius(68)
print(ergebnis)  # Ausgabe: 20.0
# Out:
# 20.0

# %% [markdown]
# ## d) For-Schleife: Zahlen 1 bis 5 ausgeben
#
# **Aufgabe:** Erkläre, wie eine einfache `for`-Schleife in Python aussieht, die die Zahlen von 1 bis einschließlich 5 ausgibt. Verwende dazu eine Schleife und die `print`-Funktion.

# %%
for zahl in range(1, 6):
    print(zahl)
# Ausgabe: 1  2  3  4  5  (jeweils in einer neuen Zeile)
# Out:
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# ## e) Zwei Arten des Imports aus Modulen
#
# **Aufgabe:** Benenne die zwei grundlegenden Arten, wie Funktionen aus Modulen in Python importiert werden können, und gib für jede Art ein Beispiel an.

# %%
# Art 1: Gesamtes Modul importieren – Zugriff immer mit Modulname als Präfix
import math
print(math.sqrt(49))   # Ausgabe: 7.0
print(math.pi)         # Ausgabe: 3.141592653589793

# Art 2: Nur bestimmte Funktion/Konstante importieren – kein Präfix nötig
from math import sqrt, pi
print(sqrt(49))        # Ausgabe: 7.0
print(pi)              # Ausgabe: 3.141592653589793
# Out:
# 7.0
# 3.141592653589793
# 7.0
# 3.141592653589793
