# %% [markdown]
# # Kapitel 7 – Widget-Referenz und Cheatsheet
#
# Dieses Notebook dient als Nachschlagewerk für die wichtigsten Tkinter-Klassen,
# Methoden und Ereignisse.

# %% [markdown]
# # Inhaltsverzeichnis
#
# - Widget-Übersicht
# - Widget-Eigenschaften
# - Widget-Methoden
# - Layout-Manager
# - Variablen
# - Events
# - Farben
# - Schriftarten
# - Messagebox
# - Filedialog
# - Canvas
# - Treeview
# - Cheatsheet

# %% [markdown]
# # Widget-Übersicht
#
# | Widget | Zweck |
# |---|---|
# | Label | Text anzeigen |
# | Button | Aktion ausführen |
# | Entry | Einzeilige Eingabe |
# | Text | Mehrzeilige Eingabe |
# | Frame | Container |
# | LabelFrame | Container mit Titel |
# | Canvas | Zeichnen |
# | Checkbutton | Ja / Nein |
# | Radiobutton | Auswahl |
# | Listbox | Listen |
# | Spinbox | Zahlen |
# | Scale | Schieberegler |
# | Menu | Menü |
# | Toplevel | Zweites Fenster |
# | Combobox | Dropdown |
# | Notebook | Tabs |
# | Progressbar | Fortschritt |
# | Treeview | Tabellen |

# %% [markdown]
# # Häufige Widget-Eigenschaften
#
# | Eigenschaft | Beschreibung |
# |---|---|
# | text | Text anzeigen |
# | font | Schriftart |
# | fg | Textfarbe |
# | bg | Hintergrundfarbe |
# | width | Breite |
# | height | Höhe |
# | padx | Innenabstand |
# | pady | Innenabstand |
# | relief | Rahmenstil |
# | state | Zustand |
# | command | Funktion bei Button |
# | image | Bild anzeigen |

# %% [markdown]
# # Häufige Methoden
#
# | Methode | Beschreibung |
# |---|---|
# | pack() | Widget anzeigen |
# | grid() | Tabellenlayout |
# | place() | Absolute Position |
# | config() | Eigenschaften ändern |
# | configure() | Eigenschaften ändern |
# | cget() | Eigenschaft lesen |
# | destroy() | Widget löschen |
# | focus() | Fokus setzen |
# | bind() | Ereignis registrieren |
# | update() | Oberfläche aktualisieren |

# %% [markdown]
# # Layout-Manager
#
# ## pack()
#
# - einfach
# - automatisch
#
# ## grid()
#
# - Formulare
# - Zeilen
# - Spalten
#
# ## place()
#
# - exakte Position

# %% [markdown]
# # Tkinter-Variablen
#
# | Klasse | Datentyp |
# |---|---|
# | StringVar | String |
# | IntVar | Integer |
# | DoubleVar | Float |
# | BooleanVar | True / False |

# %% [markdown]
# # Wichtige Events
#
# | Event | Beschreibung |
# |---|---|
# | <Button-1> | Linksklick |
# | <Button-3> | Rechtsklick |
# | <Double-Button-1> | Doppelklick |
# | <Motion> | Maus bewegen |
# | <Enter> | Maus betritt Widget |
# | <Leave> | Maus verlässt Widget |
# | <Return> | Enter |
# | <Escape> | Escape |
# | <Key> | Taste gedrückt |
# | <FocusIn> | Fokus erhalten |
# | <FocusOut> | Fokus verloren |

# %% [markdown]
# # Farben
#
# ## Standardfarben
#
# - white
# - black
# - red
# - blue
# - green
# - yellow
# - orange
# - gray
# - pink
# - cyan
#
# ## Hex-Farben
#
# ```python
# #FF0000
# #00FF00
# #0000FF
# ```

# %% [markdown]
# # Schriftarten
#
# ```python
# ("Arial",14)
#
# ("Arial",16,"bold")
#
# ("Arial",16,"italic")
#
# ("Arial",16,"underline")
# ```

# %% [markdown]
# # Messagebox
#
# ```python
# showinfo()
#
# showwarning()
#
# showerror()
#
# askyesno()
#
# askokcancel()
#
# askretrycancel()
# ```

# %% [markdown]
# # Filedialog
#
# ```python
# askopenfilename()
#
# asksaveasfilename()
#
# askdirectory()
# ```

# %% [markdown]
# # Canvas
#
# Wichtige Methoden
#
# ```python
# create_line()
#
# create_rectangle()
#
# create_oval()
#
# create_polygon()
#
# create_arc()
#
# create_text()
#
# create_image()
# ```

# %% [markdown]
# # Treeview
#
# Wichtige Methoden
#
# ```python
# heading()
#
# column()
#
# insert()
#
# delete()
#
# selection()
#
# item()
#
# focus()
# ```

# %% [markdown]
# # Cheatsheet
#
# ## Fenster
#
# ```python
# root = tk.Tk()
# root.mainloop()
# ```
#
# ## Label
#
# ```python
# tk.Label(root,text="Hallo")
# ```
#
# ## Button
#
# ```python
# tk.Button(root,text="OK")
# ```
#
# ## Entry
#
# ```python
# entry.get()
# entry.insert(0,"Text")
# entry.delete(0,"end")
# ```
#
# ## Text
#
# ```python
# text.get("1.0","end")
# ```
#
# ## Listbox
#
# ```python
# insert()
# delete()
# get()
# ```
#
# ## Canvas
#
# ```python
# create_rectangle()
# ```
#
# ## Messagebox
#
# ```python
# messagebox.showinfo()
# ```
#
# ## Combobox
#
# ```python
# combo.current(0)
# combo.get()
# ```
#
# ## Treeview
#
# ```python
# insert()
# selection()
# ```
